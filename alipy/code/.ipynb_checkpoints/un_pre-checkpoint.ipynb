# %% [markdown]
# ### 1. 线下
#     1.词向量，
#         1.1 分词，训练接下来呢？
#     2. 句向量
#         2.1 分词，训练句子。
#
# ### 2.线上
#     1.初赛只需要分词就可以了。
#     2.复赛
#       2.1 如果线上数据量变大，可能需要先用所有的单词初始化，然后单步训练。

# %%
import jieba 
import gensim
import pandas as pd
import numpy as np
import jieba.analyse
# Out:
# F:\app\anaconda\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#read file
def read1():
    '''
    读取并保存第一次
    '''
    file1=r'../data/atec_nlp_sim_train.csv'
    file2=r'../data/atec_nlp_sim_train_add.csv'
    t1=pd.read_csv(file1,index_col=None,header=None,encoding='utf-8',sep='\t')
    t2=pd.read_csv(file2,index_col=None,header=None,encoding='utf-8',sep='\t')
    train=pd.concat([t1,t2],axis=0)
    return train
#read1().to_csv('../data/nlp_train.csv',sep='\t',encoding='utf-8',header=None,index=None)

def read2():
    '''
    第一次读后的结果保存之后在读取
    '''
    file=r'../data/nlp_train.csv'
    train=pd.read_csv(file,sep='\t',encoding='utf-8',header=None,index_col=None)
    return train
train=read2()

# %% [markdown]
# * 1.1 字符串

# %%
def sent_append(df):
    '''
    把训练集的字符串结合起来。
    **莫名其妙出来一个\ufeff
    '''
    str_append=df.loc[:,1].append(df.loc[:,2]).reset_index(drop=True)
    return str_append.values
sentence=sent_append(train)

# %% [markdown]
# * 1.2分词

# %% [markdown]
# * 包含词性的分词

# %%
from jieba import posseg 
def cut_pseg(sentences):
    '''包含词性的分词
    '''
    jieba.add_word('花呗')
    jieba.add_word('借呗')
    sent_cut=[list(posseg.cut(i)) for i in sentences]
    word=[[j.word for j in i] for i in sent_cut]
    flag=[[j.flag for j in i] for i in sent_cut]
    return word,flag

# %% [markdown]
# * 普通的分词

# %%
def cut_sent(sentences):
    '''分词，用空格隔开
    '''
    jieba.add_word('花呗')
    jieba.add_word('借呗')
    sent_cut=[' '.join(jieba.cut(i,HMM=True)) for i in sentences]
    return sent_cut
sent_cut=cut_sent(sentence)

# %% [markdown]
# * 把分词后的数据写入到文档中

# %%
sent_cut[0]
# Out:
# '\ufeff 怎么 更改 花呗 手机号码'

# %%
def write_sentences(sent):
    '''
    把数据写入文档中,需要先分词
    '''    
    with open('../data/sentences.txt','w',encoding='utf-8') as f:        
        for i in sent:
            f.write(i+'\n')
write_sentences(sent_cut)

# %% [markdown]
# * 1.3 词向量

# %%
import gensim
from gensim.models import word2vec

# %%
model=word2vec.Word2Vec(sent_cut,min_count=1,iter=100)

# %% [markdown]
# * 保存

# %%
model.save('../model/model')
model=word2vec.Word2Vec.load('../model/model')

# %% [markdown]
# * 利用以上的信息训练网络

# %% [markdown]
# ####  一般特征
# 句子长度，
# * 多个版本的数据

# %% [markdown]
# #### 5. 文档和文中对应的位置

# %%
def get_vector()

# %% [markdown]
# ## 3. 句向量
# * doc2vec [参考](https://radimrehurek.com/gensim/models/doc2vec.html)

# %%
help(gensim.models.Doc2Vec)
# Out:
# Help on class Doc2Vec in module gensim.models.doc2vec:
#
# class Doc2Vec(gensim.models.base_any2vec.BaseWordEmbeddingsModel)
#  |  Class for training, using and evaluating neural networks described in http://arxiv.org/pdf/1405.4053v2.pdf
#  |
#  |  Method resolution order:
#  |      Doc2Vec
#  |      gensim.models.base_any2vec.BaseWordEmbeddingsModel
#  |      gensim.models.base_any2vec.BaseAny2VecModel
#  |      gensim.utils.SaveLoad
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, tag)
#  |
#  |  __init__(self, documents=None, dm_mean=None, dm=1, dbow_words=0, dm_concat=0, dm_tag_count=1, docvecs=None, docvecs_mapfile=None, comment=None, trim_rule=None, callbacks=(), **kwargs)
#  |      Initialize the model from an iterable of `documents`. Each document is a
#  |      TaggedDocument object that will be used for training.
#  |
#  |      Parameters
#  |      ----------
#  |      documents : iterable of iterables
#  |          The `documents` iterable can be simply a list of TaggedDocument elements, but for larger corpora,
#  |          consider an iterable that streams the documents directly from disk/network.
#  |          If you don't supply `documents`, the model is left uninitialized -- use if
#  |          you plan to initialize it in some other way.
#  |
#  |      dm : int {1,0}
#  |          Defines the training algorithm. If `dm=1`, 'distributed memory' (PV-DM) is used.
#  |          Otherwise, `distributed bag of words` (PV-DBOW) is employed.
#  |
#  |      size : int
#  |          Dimensionality of the feature vectors.
#  |      window : int
#  |          The maximum distance between the current and predicted word within a sentence.
#  |      alpha : float
#  |          The initial learning rate.
#  |      min_alpha : float
#  |          Learning rate will linearly drop to `min_alpha` as training progresses.
#  |      seed : int
#  |          Seed for the random number generator. Initial vectors for each word are seeded with a hash of
#  |          the concatenation of word + `str(seed)`. Note that for a fully deterministically-reproducible run,
#  |          you must also limit the model to a single worker thread (`workers=1`), to eliminate ordering jitter
#  |          from OS thread scheduling. (In Python 3, reproducibility between interpreter launches also requires
#  |          use of the `PYTHONHASHSEED` environment variable to control hash randomization).
#  |      min_count : int
#  |          Ignores all words with total frequency lower than this.
#  |      max_vocab_size : int
#  |          Limits the RAM during vocabulary building; if there are more unique
#  |          words than this, then prune the infrequent ones. Every 10 million word types need about 1GB of RAM.
#  |          Set to `None` for no limit.
#  |      sample : float
#  |          The threshold for configuring which higher-frequency words are randomly downsampled,
#  |          useful range is (0, 1e-5).
#  |      workers : int
#  |          Use these many worker threads to train the model (=faster training with multicore machines).
#  |      iter : int
#  |          Number of iterations (epochs) over the corpus.
#  |      hs : int {1,0}
#  |          If 1, hierarchical softmax will be used for model training.
#  |          If set to 0, and `negative` is non-zero, negative sampling will be used.
#  |      negative : int
#  |          If > 0, negative sampling will be used, the int for negative specifies how many "noise words"
#  |          should be drawn (usually between 5-20).
#  |          If set to 0, no negative sampling is used.
#  |      dm_mean : int {1,0}
#  |          If 0 , use the sum of the context word vectors. If 1, use the mean.
#  |          Only applies when `dm` is used in non-concatenative mode.
#  |      dm_concat : int {1,0}
#  |          If 1, use concatenation of context vectors rather than sum/average;
#  |          Note concatenation results in a much-larger model, as the input
#  |          is no longer the size of one (sampled or arithmetically combined) word vector, but the
#  |          size of the tag(s) and all words in the context strung together.
#  |      dm_tag_count : int
#  |          Expected constant number of document tags per document, when using
#  |          dm_concat mode; default is 1.
#  |      dbow_words : int {1,0}
#  |          If set to 1 trains word-vectors (in skip-gram fashion) simultaneous with DBOW
#  |          doc-vector training; If 0, only trains doc-vectors (faster).
#  |      trim_rule : function
#  |          Vocabulary trimming rule, specifies whether certain words should remain in the vocabulary,
#  |          be trimmed away, or handled using the default (discard if word count < min_count).
#  |          Can be None (min_count will be used, look to :func:`~gensim.utils.keep_vocab_item`),
#  |          or a callable that accepts parameters (word, count, min_count) and returns either
#  |          :attr:`gensim.utils.RULE_DISCARD`, :attr:`gensim.utils.RULE_KEEP` or :attr:`gensim.utils.RULE_DEFAULT`.
#  |          Note: The rule, if given, is only used to prune vocabulary during build_vocab() and is not stored as part
#  |          of the model.
#  |      callbacks : :obj: `list` of :obj: `~gensim.models.callbacks.CallbackAny2Vec`
#  |          List of callbacks that need to be executed/run at specific stages during training.
#  |
#  |  __str__(self)
#  |      Abbreviated name reflecting major configuration paramaters.
#  |
#  |  build_vocab(self, documents, update=False, progress_per=10000, keep_raw_vocab=False, trim_rule=None, **kwargs)
#  |      Build vocabulary from a sequence of sentences (can be a once-only generator stream).
#  |      Each sentence is a iterable of iterables (can simply be a list of unicode strings too).
#  |
#  |      Parameters
#  |      ----------
#  |      documents : iterable of iterables
#  |          The `documents` iterable can be simply a list of TaggedDocument elements, but for larger corpora,
#  |          consider an iterable that streams the documents directly from disk/network.
#  |          See :class:`~gensim.models.doc2vec.TaggedBrownCorpus` or :class:`~gensim.models.doc2vec.TaggedLineDocument`
#  |          in :mod:`~gensim.models.doc2vec` module for such examples.
#  |      keep_raw_vocab : bool
#  |          If not true, delete the raw vocabulary after the scaling is done and free up RAM.
#  |      trim_rule : function
#  |          Vocabulary trimming rule, specifies whether certain words should remain in the vocabulary,
#  |          be trimmed away, or handled using the default (discard if word count < min_count).
#  |          Can be None (min_count will be used, look to :func:`~gensim.utils.keep_vocab_item`),
#  |          or a callable that accepts parameters (word, count, min_count) and returns either
#  |          :attr:`gensim.utils.RULE_DISCARD`, :attr:`gensim.utils.RULE_KEEP` or :attr:`gensim.utils.RULE_DEFAULT`.
#  |          Note: The rule, if given, is only used to prune vocabulary during build_vocab() and is not stored as part
#  |          of the model.
#  |      progress_per : int
#  |          Indicates how many words to process before showing/updating the progress.
#  |      update : bool
#  |          If true, the new words in `sentences` will be added to model's vocab.
#  |
#  |  build_vocab_from_freq(self, word_freq, keep_raw_vocab=False, corpus_count=None, trim_rule=None, update=False)
#  |      Build vocabulary from a dictionary of word frequencies.
#  |      Build model vocabulary from a passed dictionary that contains (word,word count).
#  |      Words must be of type unicode strings.
#  |
#  |      Parameters
#  |      ----------
#  |      word_freq : dict
#  |          Word,Word_Count dictionary.
#  |      keep_raw_vocab : bool
#  |          If not true, delete the raw vocabulary after the scaling is done and free up RAM.
#  |      corpus_count : int
#  |          Even if no corpus is provided, this argument can set corpus_count explicitly.
#  |      trim_rule : function
#  |          Vocabulary trimming rule, specifies whether certain words should remain in the vocabulary,
#  |          be trimmed away, or handled using the default (discard if word count < min_count).
#  |          Can be None (min_count will be used, look to :func:`~gensim.utils.keep_vocab_item`),
#  |          or a callable that accepts parameters (word, count, min_count) and returns either
#  |          :attr:`gensim.utils.RULE_DISCARD`, :attr:`gensim.utils.RULE_KEEP` or :attr:`gensim.utils.RULE_DEFAULT`.
#  |          Note: The rule, if given, is only used to prune vocabulary during build_vocab() and is not stored as part
#  |          of the model.
#  |      update : bool
#  |          If true, the new provided words in `word_freq` dict will be added to model's vocab.
#  |
#  |      Examples
#  |      --------
#  |      >>> from gensim.models.word2vec import Word2Vec
#  |      >>> model= Word2Vec()
#  |      >>> model.build_vocab_from_freq({"Word1": 15, "Word2": 20})
#  |
#  |  clear_sims(self)
#  |
#  |  delete_temporary_training_data(self, keep_doctags_vectors=True, keep_inference=True)
#  |      Discard parameters that are used in training and score. Use if you're sure you're done training a model.
#  |
#  |      Parameters
#  |      ----------
#  |      keep_doctags_vectors : bool
#  |          Set `keep_doctags_vectors` to False if you don't want to save doctags vectors,
#  |          in this case you can't to use docvecs's most_similar, similarity etc. methods.
#  |      keep_inference : bool
#  |          Set `keep_inference` to False if you don't want to store parameters that is used for infer_vector method
#  |
#  |  estimate_memory(self, vocab_size=None, report=None)
#  |      Estimate required memory for a model using current settings.
#  |
#  |  estimated_lookup_memory(self)
#  |      Estimated memory for tag lookup; 0 if using pure int tags.
#  |
#  |  infer_vector(self, doc_words, alpha=0.1, min_alpha=0.0001, steps=5)
#  |      Infer a vector for given post-bulk training document.
#  |
#  |      Parameters
#  |      ----------
#  |      doc_words : :obj: `list` of :obj: `str`
#  |          Document should be a list of (word) tokens.
#  |      alpha : float
#  |          The initial learning rate.
#  |      min_alpha : float
#  |          Learning rate will linearly drop to `min_alpha` as training progresses.
#  |      steps : int
#  |          Number of times to train the new document.
#  |
#  |      Returns
#  |      -------
#  |      :obj: `numpy.ndarray`
#  |          Returns the inferred vector for the new document.
#  |
#  |  init_sims(self, replace=False)
#  |      Precompute L2-normalized vectors.
#  |
#  |      If `replace` is set, forget the original vectors and only keep the normalized
#  |      ones = saves lots of memory!
#  |
#  |      Note that you **cannot continue training or inference** after doing a replace.
#  |      The model becomes effectively read-only = you can call `most_similar`, `similarity`
#  |      etc., but not `train` or `infer_vector`.
#  |
#  |  reset_from(self, other_model)
#  |      Reuse shareable structures from other_model.
#  |
#  |  save_word2vec_format(self, fname, doctag_vec=False, word_vec=True, prefix='*dt_', fvocab=None, binary=False)
#  |      Store the input-hidden weight matrix in the same format used by the original
#  |      C word2vec-tool, for compatibility.
#  |
#  |      Parameters
#  |      ----------
#  |      fname : str
#  |          The file path used to save the vectors in.
#  |      doctag_vec : bool
#  |          Indicates whether to store document vectors.
#  |      word_vec : bool
#  |          Indicates whether to store word vectors.
#  |      prefix : str
#  |          Uniquely identifies doctags from word vocab, and avoids collision
#  |          in case of repeated string in doctag and word vocab.
#  |      fvocab : str
#  |          Optional file path used to save the vocabulary
#  |      binary : bool
#  |          If True, the data wil be saved in binary word2vec format, else it will be saved in plain text.
#  |
#  |  train(self, documents, total_examples=None, total_words=None, epochs=None, start_alpha=None, end_alpha=None, word_count=0, queue_factor=2, report_delay=1.0, callbacks=())
#  |      Update the model's neural weights from a sequence of sentences (can be a once-only generator stream).
#  |      The `documents` iterable can be simply a list of TaggedDocument elements.
#  |
#  |      To support linear learning-rate decay from (initial) alpha to min_alpha, and accurate
#  |      progress-percentage logging, either total_examples (count of sentences) or total_words (count of
#  |      raw words in sentences) **MUST** be provided (if the corpus is the same as was provided to
#  |      :meth:`~gensim.models.word2vec.Word2Vec.build_vocab()`, the count of examples in that corpus
#  |      will be available in the model's :attr:`corpus_count` property).
#  |
#  |      To avoid common mistakes around the model's ability to do multiple training passes itself, an
#  |      explicit `epochs` argument **MUST** be provided. In the common and recommended case,
#  |      where :meth:`~gensim.models.word2vec.Word2Vec.train()` is only called once,
#  |      the model's cached `iter` value should be supplied as `epochs` value.
#  |
#  |      Parameters
#  |      ----------
#  |      documents : iterable of iterables
#  |          The `documents` iterable can be simply a list of TaggedDocument elements, but for larger corpora,
#  |          consider an iterable that streams the documents directly from disk/network.
#  |          See :class:`~gensim.models.doc2vec.TaggedBrownCorpus` or :class:`~gensim.models.doc2vec.TaggedLineDocument`
#  |          in :mod:`~gensim.models.doc2vec` module for such examples.
#  |      total_examples : int
#  |          Count of sentences.
#  |      total_words : int
#  |          Count of raw words in documents.
#  |      epochs : int
#  |          Number of iterations (epochs) over the corpus.
#  |      start_alpha : float
#  |          Initial learning rate.
#  |      end_alpha : float
#  |          Final learning rate. Drops linearly from `start_alpha`.
#  |      word_count : int
#  |          Count of words already trained. Set this to 0 for the usual
#  |          case of training on all words in sentences.
#  |      queue_factor : int
#  |          Multiplier for size of queue (number of workers * queue_factor).
#  |      report_delay : float
#  |          Seconds to wait before reporting progress.
#  |      callbacks : :obj: `list` of :obj: `~gensim.models.callbacks.CallbackAny2Vec`
#  |          List of callbacks that need to be executed/run at specific stages during training.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  load(*args, **kwargs) from builtins.type
#  |      Load a previously saved object (using :meth:`~gensim.utils.SaveLoad.save`) from file.
#  |
#  |      Parameters
#  |      ----------
#  |      fname : str
#  |          Path to file that contains needed object.
#  |      mmap : str, optional
#  |          Memory-map option.  If the object was saved with large arrays stored separately, you can load these arrays
#  |          via mmap (shared memory) using `mmap='r'.
#  |          If the file being loaded is compressed (either '.gz' or '.bz2'), then `mmap=None` **must be** set.
#  |
#  |      See Also
#  |      --------
#  |      :meth:`~gensim.utils.SaveLoad.save`
#  |
#  |      Returns
#  |      -------
#  |      object
#  |          Object loaded from `fname`.
#  |
#  |      Raises
#  |      ------
#  |      IOError
#  |          When methods are called on instance (should be called from class).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  dbow
#  |      int {1,0} : `dbow=1` indicates `distributed bag of words` (PV-DBOW) else
#  |      'distributed memory' (PV-DM) is used.
#  |
#  |  dm
#  |      int {1,0} : `dm=1` indicates 'distributed memory' (PV-DM) else
#  |      `distributed bag of words` (PV-DBOW) is used.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from gensim.models.base_any2vec.BaseWordEmbeddingsModel:
#  |
#  |  doesnt_match(self, words)
#  |      Deprecated. Use self.wv.doesnt_match() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.doesnt_match`
#  |
#  |  evaluate_word_pairs(self, pairs, delimiter='\t', restrict_vocab=300000, case_insensitive=True, dummy4unknown=False)
#  |      Deprecated. Use self.wv.evaluate_word_pairs() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.evaluate_word_pairs`
#  |
#  |  most_similar(self, positive=None, negative=None, topn=10, restrict_vocab=None, indexer=None)
#  |      Deprecated. Use self.wv.most_similar() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.most_similar`
#  |
#  |  most_similar_cosmul(self, positive=None, negative=None, topn=10)
#  |      Deprecated. Use self.wv.most_similar_cosmul() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.most_similar_cosmul`
#  |
#  |  n_similarity(self, ws1, ws2)
#  |      Deprecated. Use self.wv.n_similarity() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.n_similarity`
#  |
#  |  similar_by_vector(self, vector, topn=10, restrict_vocab=None)
#  |      Deprecated. Use self.wv.similar_by_vector() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.similar_by_vector`
#  |
#  |  similar_by_word(self, word, topn=10, restrict_vocab=None)
#  |      Deprecated. Use self.wv.similar_by_word() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.similar_by_word`
#  |
#  |  similarity(self, w1, w2)
#  |      Deprecated. Use self.wv.similarity() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.similarity`
#  |
#  |  wmdistance(self, document1, document2)
#  |      Deprecated. Use self.wv.wmdistance() instead.
#  |      Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.wmdistance`
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from gensim.models.base_any2vec.BaseWordEmbeddingsModel:
#  |
#  |  cum_table
#  |
#  |  hashfxn
#  |
#  |  iter
#  |
#  |  layer1_size
#  |
#  |  min_count
#  |
#  |  sample
#  |
#  |  syn0_lockf
#  |
#  |  syn1
#  |
#  |  syn1neg
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from gensim.models.base_any2vec.BaseAny2VecModel:
#  |
#  |  save(self, fname_or_handle, **kwargs)
#  |      Save the object to file.
#  |
#  |      Parameters
#  |      ----------
#  |      fname_or_handle : str or file-like
#  |          Path to output file or already opened file-like object. If the object is a file handle,
#  |          no special array handling will be performed, all attributes will be saved to the same file.
#  |      separately : list of str or None, optional
#  |          If None -  automatically detect large numpy/scipy.sparse arrays in the object being stored, and store
#  |          them into separate files. This avoids pickle memory errors and allows mmap'ing large arrays
#  |          back on load efficiently.
#  |          If list of str - this attributes will be stored in separate files, the automatic check
#  |          is not performed in this case.
#  |      sep_limit : int
#  |          Limit for automatic separation.
#  |      ignore : frozenset of str
#  |          Attributes that shouldn't be serialize/store.
#  |      pickle_protocol : int
#  |          Protocol number for pickle.
#  |
#  |      See Also
#  |      --------
#  |      :meth:`~gensim.utils.SaveLoad.load`
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from gensim.utils.SaveLoad:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ### 3.1 直接读取文件

# %%
documents = gensim.models.doc2vec.TaggedLineDocument('../data/sentences.txt')

# %%
doc2vec_doc=gensim.models.Doc2Vec(documents,epochs=1000,window=4,workers=6)

# %%
doc2vec_doc.wv.vocab
# Out:
# {'怎么': <gensim.models.keyedvectors.Vocab at 0x16ac8d57438>,
#  '更改': <gensim.models.keyedvectors.Vocab at 0x16ac8d57400>,
#  '花呗': <gensim.models.keyedvectors.Vocab at 0x16ac8d57470>,
#  '手机号码': <gensim.models.keyedvectors.Vocab at 0x16ac8d574a8>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x16ac8d574e0>,
#  '开': <gensim.models.keyedvectors.Vocab at 0x16ac8d57518>,
#  '不了': <gensim.models.keyedvectors.Vocab at 0x16ac8d57550>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x16ac8d57588>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x16ac8d575c0>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x16ac8d575f8>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x16ac8d57630>,
#  '？': <gensim.models.keyedvectors.Vocab at 0x16ac8d57668>,
#  '完事': <gensim.models.keyedvectors.Vocab at 0x16ac8d576a0>,
#  '冻结': <gensim.models.keyedvectors.Vocab at 0x16ac8d576d8>,
#  '以后': <gensim.models.keyedvectors.Vocab at 0x16ac8d57710>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x16ac8d57748>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x16ac8d57780>,
#  '开通': <gensim.models.keyedvectors.Vocab at 0x16ac8d577b8>,
#  '吗': <gensim.models.keyedvectors.Vocab at 0x16ac8d577f0>,
#  '如何': <gensim.models.keyedvectors.Vocab at 0x16ac8d57828>,
#  '关闭': <gensim.models.keyedvectors.Vocab at 0x16ac8d57860>,
#  '借呗': <gensim.models.keyedvectors.Vocab at 0x16ac8d57898>,
#  '扫码': <gensim.models.keyedvectors.Vocab at 0x16ac8d578d0>,
#  '付钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d57908>,
#  '逾期': <gensim.models.keyedvectors.Vocab at 0x16ac8d57940>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x16ac8d57978>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x16ac8d579b0>,
#  '分期': <gensim.models.keyedvectors.Vocab at 0x16ac8d579e8>,
#  '清空': <gensim.models.keyedvectors.Vocab at 0x16ac8d57a20>,
#  '短信': <gensim.models.keyedvectors.Vocab at 0x16ac8d57a58>,
#  '通知': <gensim.models.keyedvectors.Vocab at 0x16ac8d57a90>,
#  '即将': <gensim.models.keyedvectors.Vocab at 0x16ac8d57ac8>,
#  '到期': <gensim.models.keyedvectors.Vocab at 0x16ac8d57b00>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x16ac8d57b38>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x16ac8d57b70>,
#  '账单': <gensim.models.keyedvectors.Vocab at 0x16ac8d57ba8>,
#  '为什么': <gensim.models.keyedvectors.Vocab at 0x16ac8d57be0>,
#  '支付': <gensim.models.keyedvectors.Vocab at 0x16ac8d57c18>,
#  '手机': <gensim.models.keyedvectors.Vocab at 0x16ac8d57c50>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x16ac8d57c88>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x16ac8d57cc0>,
#  '双': <gensim.models.keyedvectors.Vocab at 0x16ac8d57cf8>,
#  '*': <gensim.models.keyedvectors.Vocab at 0x16ac8d57d30>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x16ac8d57d68>,
#  '临时': <gensim.models.keyedvectors.Vocab at 0x16ac8d57da0>,
#  '额度': <gensim.models.keyedvectors.Vocab at 0x16ac8d57dd8>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x16ac8d57e10>,
#  '什么': <gensim.models.keyedvectors.Vocab at 0x16ac8d57e48>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x16ac8d57e80>,
#  '每月': <gensim.models.keyedvectors.Vocab at 0x16ac8d57eb8>,
#  '最低': <gensim.models.keyedvectors.Vocab at 0x16ac8d57ef0>,
#  '还款': <gensim.models.keyedvectors.Vocab at 0x16ac8d57f28>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x16ac8d57f60>,
#  '万分之': <gensim.models.keyedvectors.Vocab at 0x16ac8d57f98>,
#  '五': <gensim.models.keyedvectors.Vocab at 0x16ac8d57fd0>,
#  '利息': <gensim.models.keyedvectors.Vocab at 0x16ac8d65048>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x16ac8d65080>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x16ac8d650b8>,
#  '蚂蚁': <gensim.models.keyedvectors.Vocab at 0x16ac8d650f0>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x16ac8d65128>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x16ac8d65160>,
#  '验证': <gensim.models.keyedvectors.Vocab at 0x16ac8d65198>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x16ac8d651d0>,
#  '未': <gensim.models.keyedvectors.Vocab at 0x16ac8d65208>,
#  '恢复': <gensim.models.keyedvectors.Vocab at 0x16ac8d65240>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x16ac8d65278>,
#  '忘记': <gensim.models.keyedvectors.Vocab at 0x16ac8d652b0>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x16ac8d652e8>,
#  '一天': <gensim.models.keyedvectors.Vocab at 0x16ac8d65320>,
#  '有事吗': <gensim.models.keyedvectors.Vocab at 0x16ac8d65358>,
#  '问': <gensim.models.keyedvectors.Vocab at 0x16ac8d65390>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x16ac8d653c8>,
#  '钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d65400>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x16ac8d65438>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x16ac8d65470>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x16ac8d654a8>,
#  '闲鱼': <gensim.models.keyedvectors.Vocab at 0x16ac8d654e0>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x16ac8d65518>,
#  '买手机': <gensim.models.keyedvectors.Vocab at 0x16ac8d65550>,
#  '时间': <gensim.models.keyedvectors.Vocab at 0x16ac8d65588>,
#  '绑定': <gensim.models.keyedvectors.Vocab at 0x16ac8d655c0>,
#  '银行卡': <gensim.models.keyedvectors.Vocab at 0x16ac8d655f8>,
#  '人脸': <gensim.models.keyedvectors.Vocab at 0x16ac8d65630>,
#  '提前': <gensim.models.keyedvectors.Vocab at 0x16ac8d65668>,
#  '第一期': <gensim.models.keyedvectors.Vocab at 0x16ac8d656a0>,
#  '付款': <gensim.models.keyedvectors.Vocab at 0x16ac8d656d8>,
#  '为何': <gensim.models.keyedvectors.Vocab at 0x16ac8d65710>,
#  '美团': <gensim.models.keyedvectors.Vocab at 0x16ac8d65748>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x16ac8d65780>,
#  '超时': <gensim.models.keyedvectors.Vocab at 0x16ac8d657b8>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x16ac8d657f0>,
#  '现在': <gensim.models.keyedvectors.Vocab at 0x16ac8d65828>,
#  '国外': <gensim.models.keyedvectors.Vocab at 0x16ac8d65860>,
#  '账户': <gensim.models.keyedvectors.Vocab at 0x16ac8d65898>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x16ac8d658d0>,
#  '退回': <gensim.models.keyedvectors.Vocab at 0x16ac8d65908>,
#  '期': <gensim.models.keyedvectors.Vocab at 0x16ac8d65940>,
#  '免息': <gensim.models.keyedvectors.Vocab at 0x16ac8d65978>,
#  '不用': <gensim.models.keyedvectors.Vocab at 0x16ac8d659b0>,
#  '的话': <gensim.models.keyedvectors.Vocab at 0x16ac8d659e8>,
#  '费用': <gensim.models.keyedvectors.Vocab at 0x16ac8d65a20>,
#  '怎样': <gensim.models.keyedvectors.Vocab at 0x16ac8d65a58>,
#  '邀请': <gensim.models.keyedvectors.Vocab at 0x16ac8d65a90>,
#  '好友': <gensim.models.keyedvectors.Vocab at 0x16ac8d65ac8>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x16ac8d65b00>,
#  '昨天': <gensim.models.keyedvectors.Vocab at 0x16ac8d65b38>,
#  '欠': <gensim.models.keyedvectors.Vocab at 0x16ac8d65b70>,
#  '多少': <gensim.models.keyedvectors.Vocab at 0x16ac8d65ba8>,
#  '提额': <gensim.models.keyedvectors.Vocab at 0x16ac8d65be0>,
#  '输入': <gensim.models.keyedvectors.Vocab at 0x16ac8d65c18>,
#  '密码': <gensim.models.keyedvectors.Vocab at 0x16ac8d65c50>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x16ac8d65c88>,
#  '给': <gensim.models.keyedvectors.Vocab at 0x16ac8d65cc0>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x16ac8d65cf8>,
#  '充': <gensim.models.keyedvectors.Vocab at 0x16ac8d65d30>,
#  '话费': <gensim.models.keyedvectors.Vocab at 0x16ac8d65d68>,
#  '自动': <gensim.models.keyedvectors.Vocab at 0x16ac8d65da0>,
#  '扣款': <gensim.models.keyedvectors.Vocab at 0x16ac8d65dd8>,
#  '放款': <gensim.models.keyedvectors.Vocab at 0x16ac8d65e10>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x16ac8d65e48>,
#  '账': <gensim.models.keyedvectors.Vocab at 0x16ac8d65e80>,
#  '上个月': <gensim.models.keyedvectors.Vocab at 0x16ac8d65eb8>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x16ac8d65ef0>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x16ac8d65f28>,
#  '是不是': <gensim.models.keyedvectors.Vocab at 0x16ac8d65f60>,
#  '每个': <gensim.models.keyedvectors.Vocab at 0x16ac8d65f98>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x16ac8d65fd0>,
#  '才能': <gensim.models.keyedvectors.Vocab at 0x16ac8d66048>,
#  '收款': <gensim.models.keyedvectors.Vocab at 0x16ac8d66080>,
#  '符合': <gensim.models.keyedvectors.Vocab at 0x16ac8d660b8>,
#  '条件': <gensim.models.keyedvectors.Vocab at 0x16ac8d660f0>,
#  '商家': <gensim.models.keyedvectors.Vocab at 0x16ac8d66128>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x16ac8d66160>,
#  '买家': <gensim.models.keyedvectors.Vocab at 0x16ac8d66198>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x16ac8d661d0>,
#  '信用度': <gensim.models.keyedvectors.Vocab at 0x16ac8d66208>,
#  '刚': <gensim.models.keyedvectors.Vocab at 0x16ac8d66240>,
#  '消费': <gensim.models.keyedvectors.Vocab at 0x16ac8d66278>,
#  '扣': <gensim.models.keyedvectors.Vocab at 0x16ac8d662b0>,
#  '卡里': <gensim.models.keyedvectors.Vocab at 0x16ac8d662e8>,
#  '没扣': <gensim.models.keyedvectors.Vocab at 0x16ac8d66320>,
#  '怎么回事': <gensim.models.keyedvectors.Vocab at 0x16ac8d66358>,
#  '删除': <gensim.models.keyedvectors.Vocab at 0x16ac8d66390>,
#  '记录': <gensim.models.keyedvectors.Vocab at 0x16ac8d663c8>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x16ac8d66400>,
#  '为啥': <gensim.models.keyedvectors.Vocab at 0x16ac8d66438>,
#  '叫': <gensim.models.keyedvectors.Vocab at 0x16ac8d66470>,
#  '交': <gensim.models.keyedvectors.Vocab at 0x16ac8d664a8>,
#  '收': <gensim.models.keyedvectors.Vocab at 0x16ac8d664e0>,
#  '顾客': <gensim.models.keyedvectors.Vocab at 0x16ac8d66518>,
#  '延长': <gensim.models.keyedvectors.Vocab at 0x16ac8d66550>,
#  '二维码': <gensim.models.keyedvectors.Vocab at 0x16ac8d66588>,
#  '支付宝': <gensim.models.keyedvectors.Vocab at 0x16ac8d665c0>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x16ac8d665f8>,
#  '找': <gensim.models.keyedvectors.Vocab at 0x16ac8d66630>,
#  '不到': <gensim.models.keyedvectors.Vocab at 0x16ac8d66668>,
#  '还清': <gensim.models.keyedvectors.Vocab at 0x16ac8d666a0>,
#  '注销': <gensim.models.keyedvectors.Vocab at 0x16ac8d666d8>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x16ac8d66710>,
#  '账号': <gensim.models.keyedvectors.Vocab at 0x16ac8d66748>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x16ac8d66780>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x16ac8d667b8>,
#  '没出': <gensim.models.keyedvectors.Vocab at 0x16ac8d667f0>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x16ac8d66828>,
#  '封': <gensim.models.keyedvectors.Vocab at 0x16ac8d66860>,
#  '帮': <gensim.models.keyedvectors.Vocab at 0x16ac8d66898>,
#  '零时': <gensim.models.keyedvectors.Vocab at 0x16ac8d668d0>,
#  '这么久': <gensim.models.keyedvectors.Vocab at 0x16ac8d66908>,
#  '体验': <gensim.models.keyedvectors.Vocab at 0x16ac8d66940>,
#  '咋': <gensim.models.keyedvectors.Vocab at 0x16ac8d66978>,
#  '老': <gensim.models.keyedvectors.Vocab at 0x16ac8d669b0>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x16ac8d669e8>,
#  '那': <gensim.models.keyedvectors.Vocab at 0x16ac8d66a20>,
#  '还款额': <gensim.models.keyedvectors.Vocab at 0x16ac8d66a58>,
#  '度': <gensim.models.keyedvectors.Vocab at 0x16ac8d66a90>,
#  '限制': <gensim.models.keyedvectors.Vocab at 0x16ac8d66ac8>,
#  '下降': <gensim.models.keyedvectors.Vocab at 0x16ac8d66b00>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x16ac8d66b38>,
#  '信用卡': <gensim.models.keyedvectors.Vocab at 0x16ac8d66b70>,
#  '码': <gensim.models.keyedvectors.Vocab at 0x16ac8d66ba8>,
#  '调': <gensim.models.keyedvectors.Vocab at 0x16ac8d66be0>,
#  '高点': <gensim.models.keyedvectors.Vocab at 0x16ac8d66c18>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x16ac8d66c50>,
#  '没用': <gensim.models.keyedvectors.Vocab at 0x16ac8d66c88>,
#  '解绑': <gensim.models.keyedvectors.Vocab at 0x16ac8d66cc0>,
#  '线下': <gensim.models.keyedvectors.Vocab at 0x16ac8d66cf8>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x16ac8d66d30>,
#  '月份': <gensim.models.keyedvectors.Vocab at 0x16ac8d66d68>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x16ac8d66da0>,
#  '刷卡': <gensim.models.keyedvectors.Vocab at 0x16ac8d66dd8>,
#  '卖家': <gensim.models.keyedvectors.Vocab at 0x16ac8d66e10>,
#  '手续费': <gensim.models.keyedvectors.Vocab at 0x16ac8d66e48>,
#  '余额': <gensim.models.keyedvectors.Vocab at 0x16ac8d66e80>,
#  '宝': <gensim.models.keyedvectors.Vocab at 0x16ac8d66eb8>,
#  '哪儿': <gensim.models.keyedvectors.Vocab at 0x16ac8d66ef0>,
#  '十二': <gensim.models.keyedvectors.Vocab at 0x16ac8d66f28>,
#  '还有': <gensim.models.keyedvectors.Vocab at 0x16ac8d66f60>,
#  '呀': <gensim.models.keyedvectors.Vocab at 0x16ac8d66f98>,
#  '方式': <gensim.models.keyedvectors.Vocab at 0x16ac8d66fd0>,
#  '添加': <gensim.models.keyedvectors.Vocab at 0x16ac8d67048>,
#  '提醒': <gensim.models.keyedvectors.Vocab at 0x16ac8d67080>,
#  '提款': <gensim.models.keyedvectors.Vocab at 0x16ac8d670b8>,
#  '金额': <gensim.models.keyedvectors.Vocab at 0x16ac8d670f0>,
#  '日期': <gensim.models.keyedvectors.Vocab at 0x16ac8d67128>,
#  '怎么样': <gensim.models.keyedvectors.Vocab at 0x16ac8d67160>,
#  '收钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d67198>,
#  '打不开': <gensim.models.keyedvectors.Vocab at 0x16ac8d671d0>,
#  '满足': <gensim.models.keyedvectors.Vocab at 0x16ac8d67208>,
#  '感觉': <gensim.models.keyedvectors.Vocab at 0x16ac8d67240>,
#  '越': <gensim.models.keyedvectors.Vocab at 0x16ac8d67278>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x16ac8d672b0>,
#  '一次': <gensim.models.keyedvectors.Vocab at 0x16ac8d672e8>,
#  '结清': <gensim.models.keyedvectors.Vocab at 0x16ac8d67320>,
#  '办理': <gensim.models.keyedvectors.Vocab at 0x16ac8d67358>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x16ac8d67390>,
#  '退': <gensim.models.keyedvectors.Vocab at 0x16ac8d673c8>,
#  '运费': <gensim.models.keyedvectors.Vocab at 0x16ac8d67400>,
#  '前天': <gensim.models.keyedvectors.Vocab at 0x16ac8d67438>,
#  '今天': <gensim.models.keyedvectors.Vocab at 0x16ac8d67470>,
#  '能够': <gensim.models.keyedvectors.Vocab at 0x16ac8d674a8>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x16ac8d674e0>,
#  '款': <gensim.models.keyedvectors.Vocab at 0x16ac8d67518>,
#  '购物': <gensim.models.keyedvectors.Vocab at 0x16ac8d67550>,
#  '津贴': <gensim.models.keyedvectors.Vocab at 0x16ac8d67588>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x16ac8d675c0>,
#  '日息': <gensim.models.keyedvectors.Vocab at 0x16ac8d675f8>,
#  '一样': <gensim.models.keyedvectors.Vocab at 0x16ac8d67630>,
#  '服务': <gensim.models.keyedvectors.Vocab at 0x16ac8d67668>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x16ac8d676a0>,
#  '限额': <gensim.models.keyedvectors.Vocab at 0x16ac8d676d8>,
#  '这用': <gensim.models.keyedvectors.Vocab at 0x16ac8d67710>,
#  '不让': <gensim.models.keyedvectors.Vocab at 0x16ac8d67748>,
#  '分期付款': <gensim.models.keyedvectors.Vocab at 0x16ac8d67780>,
#  '还款期': <gensim.models.keyedvectors.Vocab at 0x16ac8d677b8>,
#  '数': <gensim.models.keyedvectors.Vocab at 0x16ac8d677f0>,
#  '里边': <gensim.models.keyedvectors.Vocab at 0x16ac8d67828>,
#  '怎么办': <gensim.models.keyedvectors.Vocab at 0x16ac8d67860>,
#  '系统': <gensim.models.keyedvectors.Vocab at 0x16ac8d67898>,
#  '繁忙': <gensim.models.keyedvectors.Vocab at 0x16ac8d678d0>,
#  '意思': <gensim.models.keyedvectors.Vocab at 0x16ac8d67908>,
#  '预定': <gensim.models.keyedvectors.Vocab at 0x16ac8d67940>,
#  '酒店': <gensim.models.keyedvectors.Vocab at 0x16ac8d67978>,
#  '电费': <gensim.models.keyedvectors.Vocab at 0x16ac8d679b0>,
#  '小心': <gensim.models.keyedvectors.Vocab at 0x16ac8d679e8>,
#  '便利店': <gensim.models.keyedvectors.Vocab at 0x16ac8d67a20>,
#  '周卡': <gensim.models.keyedvectors.Vocab at 0x16ac8d67a58>,
#  '取消': <gensim.models.keyedvectors.Vocab at 0x16ac8d67a90>,
#  '次数': <gensim.models.keyedvectors.Vocab at 0x16ac8d67ac8>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x16ac8d67b00>,
#  'ma': <gensim.models.keyedvectors.Vocab at 0x16ac8d67b38>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x16ac8d67b70>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x16ac8d67ba8>,
#  '买': <gensim.models.keyedvectors.Vocab at 0x16ac8d67be0>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x16ac8d67c18>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x16ac8d67c50>,
#  '不是': <gensim.models.keyedvectors.Vocab at 0x16ac8d67c88>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x16ac8d67cc0>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x16ac8d67cf8>,
#  '个人': <gensim.models.keyedvectors.Vocab at 0x16ac8d67d30>,
#  '吧': <gensim.models.keyedvectors.Vocab at 0x16ac8d67d68>,
#  '我点': <gensim.models.keyedvectors.Vocab at 0x16ac8d67da0>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x16ac8d67dd8>,
#  '应': <gensim.models.keyedvectors.Vocab at 0x16ac8d67e10>,
#  '退款': <gensim.models.keyedvectors.Vocab at 0x16ac8d67e48>,
#  '确认': <gensim.models.keyedvectors.Vocab at 0x16ac8d67e80>,
#  '收货': <gensim.models.keyedvectors.Vocab at 0x16ac8d67eb8>,
#  '原来': <gensim.models.keyedvectors.Vocab at 0x16ac8d67ef0>,
#  '价钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d67f28>,
#  '操作': <gensim.models.keyedvectors.Vocab at 0x16ac8d67f60>,
#  '主动': <gensim.models.keyedvectors.Vocab at 0x16ac8d67f98>,
#  '这次': <gensim.models.keyedvectors.Vocab at 0x16ac8d67fd0>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x16ac8d69048>,
#  '点': <gensim.models.keyedvectors.Vocab at 0x16ac8d69080>,
#  '提': <gensim.models.keyedvectors.Vocab at 0x16ac8d690b8>,
#  '永久': <gensim.models.keyedvectors.Vocab at 0x16ac8d690f0>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x16ac8d69128>,
#  '一张': <gensim.models.keyedvectors.Vocab at 0x16ac8d69160>,
#  '身份证': <gensim.models.keyedvectors.Vocab at 0x16ac8d69198>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x16ac8d691d0>,
#  '重新': <gensim.models.keyedvectors.Vocab at 0x16ac8d69208>,
#  '评估': <gensim.models.keyedvectors.Vocab at 0x16ac8d69240>,
#  '所以': <gensim.models.keyedvectors.Vocab at 0x16ac8d69278>,
#  '下个月': <gensim.models.keyedvectors.Vocab at 0x16ac8d692b0>,
#  '最后': <gensim.models.keyedvectors.Vocab at 0x16ac8d692e8>,
#  '修改': <gensim.models.keyedvectors.Vocab at 0x16ac8d69320>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x16ac8d69358>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x16ac8d69390>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x16ac8d693c8>,
#  '我换': <gensim.models.keyedvectors.Vocab at 0x16ac8d69400>,
#  '周期': <gensim.models.keyedvectors.Vocab at 0x16ac8d69438>,
#  '改': <gensim.models.keyedvectors.Vocab at 0x16ac8d69470>,
#  '立减': <gensim.models.keyedvectors.Vocab at 0x16ac8d694a8>,
#  '本月': <gensim.models.keyedvectors.Vocab at 0x16ac8d694e0>,
#  '号': <gensim.models.keyedvectors.Vocab at 0x16ac8d69518>,
#  '借款': <gensim.models.keyedvectors.Vocab at 0x16ac8d69550>,
#  '支持': <gensim.models.keyedvectors.Vocab at 0x16ac8d69588>,
#  '不良': <gensim.models.keyedvectors.Vocab at 0x16ac8d695c0>,
#  '不想': <gensim.models.keyedvectors.Vocab at 0x16ac8d695f8>,
#  '电脑': <gensim.models.keyedvectors.Vocab at 0x16ac8d69630>,
#  '一万': <gensim.models.keyedvectors.Vocab at 0x16ac8d69668>,
#  '收费': <gensim.models.keyedvectors.Vocab at 0x16ac8d696a0>,
#  '淘宝': <gensim.models.keyedvectors.Vocab at 0x16ac8d696d8>,
#  '怎': <gensim.models.keyedvectors.Vocab at 0x16ac8d69710>,
#  '带': <gensim.models.keyedvectors.Vocab at 0x16ac8d69748>,
#  '道': <gensim.models.keyedvectors.Vocab at 0x16ac8d69780>,
#  '第二个': <gensim.models.keyedvectors.Vocab at 0x16ac8d697b8>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x16ac8d697f0>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x16ac8d69828>,
#  '能换': <gensim.models.keyedvectors.Vocab at 0x16ac8d69860>,
#  '码能': <gensim.models.keyedvectors.Vocab at 0x16ac8d69898>,
#  '游戏': <gensim.models.keyedvectors.Vocab at 0x16ac8d698d0>,
#  '充值': <gensim.models.keyedvectors.Vocab at 0x16ac8d69908>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x16ac8d69940>,
#  '再用': <gensim.models.keyedvectors.Vocab at 0x16ac8d69978>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x16ac8d699b0>,
#  '好像': <gensim.models.keyedvectors.Vocab at 0x16ac8d699e8>,
#  '几天': <gensim.models.keyedvectors.Vocab at 0x16ac8d69a20>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x16ac8d69a58>,
#  '三四个': <gensim.models.keyedvectors.Vocab at 0x16ac8d69a90>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x16ac8d69ac8>,
#  '东西': <gensim.models.keyedvectors.Vocab at 0x16ac8d69b00>,
#  '嘛': <gensim.models.keyedvectors.Vocab at 0x16ac8d69b38>,
#  '大额': <gensim.models.keyedvectors.Vocab at 0x16ac8d69b70>,
#  '那种': <gensim.models.keyedvectors.Vocab at 0x16ac8d69ba8>,
#  '以前': <gensim.models.keyedvectors.Vocab at 0x16ac8d69be0>,
#  '号码': <gensim.models.keyedvectors.Vocab at 0x16ac8d69c18>,
#  '换': <gensim.models.keyedvectors.Vocab at 0x16ac8d69c50>,
#  '钱放': <gensim.models.keyedvectors.Vocab at 0x16ac8d69c88>,
#  '推迟': <gensim.models.keyedvectors.Vocab at 0x16ac8d69cc0>,
#  '上面': <gensim.models.keyedvectors.Vocab at 0x16ac8d69cf8>,
#  '签收': <gensim.models.keyedvectors.Vocab at 0x16ac8d69d30>,
#  '收到': <gensim.models.keyedvectors.Vocab at 0x16ac8d69d68>,
#  '货物': <gensim.models.keyedvectors.Vocab at 0x16ac8d69da0>,
#  '我用': <gensim.models.keyedvectors.Vocab at 0x16ac8d69dd8>,
#  '共享': <gensim.models.keyedvectors.Vocab at 0x16ac8d69e10>,
#  '单车': <gensim.models.keyedvectors.Vocab at 0x16ac8d69e48>,
#  '押金': <gensim.models.keyedvectors.Vocab at 0x16ac8d69e80>,
#  '申请': <gensim.models.keyedvectors.Vocab at 0x16ac8d69eb8>,
#  '再次': <gensim.models.keyedvectors.Vocab at 0x16ac8d69ef0>,
#  '住': <gensim.models.keyedvectors.Vocab at 0x16ac8d69f28>,
#  '切换': <gensim.models.keyedvectors.Vocab at 0x16ac8d69f60>,
#  '手机号': <gensim.models.keyedvectors.Vocab at 0x16ac8d69f98>,
#  '授权': <gensim.models.keyedvectors.Vocab at 0x16ac8d69fd0>,
#  '比如': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b048>,
#  '早': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b080>,
#  '晚': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b0b8>,
#  '数额': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b0f0>,
#  '暂停': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b128>,
#  '刚刚': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b160>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b198>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b1d0>,
#  '快': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b208>,
#  '以为': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b240>,
#  '借': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b278>,
#  '块钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b2b0>,
#  '提现': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b2e8>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b320>,
#  '这笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b358>,
#  '还要': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b390>,
#  '绑': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b3c8>,
#  '坏': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b400>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b438>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b470>,
#  '变': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b4a8>,
#  '昨晚': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b4e0>,
#  '查询': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b518>,
#  '一下': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b550>,
#  '提示': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b588>,
#  '降低': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b5c0>,
#  '信用': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b5f8>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b630>,
#  '代付': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b668>,
#  '后会': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b6a0>,
#  '么': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b6d8>,
#  '过期': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b710>,
#  '马上': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b748>,
#  '少': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b780>,
#  '双十': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b7b8>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b7f0>,
#  '看下': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b828>,
#  '多久': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b860>,
#  '升级': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b898>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b8d0>,
#  '网商贷': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b908>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b940>,
#  '退货': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b978>,
#  '我想': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b9b0>,
#  '买个': <gensim.models.keyedvectors.Vocab at 0x16ac8d6b9e8>,
#  '不够': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ba20>,
#  '别人': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ba58>,
#  '付': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ba90>,
#  '而是': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bac8>,
#  '同一个': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bb00>,
#  '新开通': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bb38>,
#  '关': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bb70>,
#  '蚁': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bba8>,
#  '变为': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bbe0>,
#  '知道': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bc18>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bc50>,
#  '红包': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bc88>,
#  '扣钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bcc0>,
#  '花': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bcf8>,
#  '里面': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bd30>,
#  '积分': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bd68>,
#  '任务': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bda0>,
#  '另外': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bdd8>,
#  '锁住': <gensim.models.keyedvectors.Vocab at 0x16ac8d6be10>,
#  '可用': <gensim.models.keyedvectors.Vocab at 0x16ac8d6be48>,
#  '解锁': <gensim.models.keyedvectors.Vocab at 0x16ac8d6be80>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x16ac8d6beb8>,
#  '客户': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bef0>,
#  '利率': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bf28>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bf60>,
#  '会员': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bf98>,
#  '关系': <gensim.models.keyedvectors.Vocab at 0x16ac8d6bfd0>,
#  '刚才': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e048>,
#  '没到': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e080>,
#  '借钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e0b8>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e0f0>,
#  '要是': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e128>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e160>,
#  '招联': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e198>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e1d0>,
#  '后能': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e208>,
#  '还期': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e240>,
#  '找人': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e278>,
#  '本来': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e2b0>,
#  '几万': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e2e8>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e320>,
#  '后来': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e358>,
#  '转入': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e390>,
#  '永远': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e3c8>,
#  '暂时': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e400>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e438>,
#  '查': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e470>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e4a8>,
#  '转': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e4e0>,
#  '用途': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e518>,
#  '要求': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e550>,
#  '哪里': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e588>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e5c0>,
#  '多分': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e5f8>,
#  '几十': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e630>,
#  '刷': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e668>,
#  '脸': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e6a0>,
#  '本人': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e6d8>,
#  '照片': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e710>,
#  '可否': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e748>,
#  '另': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e780>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e7b8>,
#  '花贝': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e7f0>,
#  '转过': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e828>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e860>,
#  '停用': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e898>,
#  '一致': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e8d0>,
#  '莫名': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e908>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e940>,
#  '帐号': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e978>,
#  '变更': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e9b0>,
#  '换成': <gensim.models.keyedvectors.Vocab at 0x16ac8d6e9e8>,
#  '邮箱': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ea20>,
#  '登录': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ea58>,
#  '中午': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ea90>,
#  '冲突': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eac8>,
#  '当月': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eb00>,
#  '卡': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eb38>,
#  '朋友': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eb70>,
#  '丢': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eba8>,
#  '补办': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ebe0>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ec18>,
#  '里': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ec50>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ec88>,
#  '指定': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ecc0>,
#  '软件': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ecf8>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ed30>,
#  '风险': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ed68>,
#  '可借': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eda0>,
#  '查查': <gensim.models.keyedvectors.Vocab at 0x16ac8d6edd8>,
#  '我来': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ee10>,
#  '火车票': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ee48>,
#  '分成': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ee80>,
#  '六个月': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eeb8>,
#  '蚂': <gensim.models.keyedvectors.Vocab at 0x16ac8d6eef0>,
#  '商品': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ef28>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ef60>,
#  '注意': <gensim.models.keyedvectors.Vocab at 0x16ac8d6ef98>,
#  '两笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d6efd0>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x16ac8d70048>,
#  '两次': <gensim.models.keyedvectors.Vocab at 0x16ac8d70080>,
#  '当天': <gensim.models.keyedvectors.Vocab at 0x16ac8d700b8>,
#  '商户': <gensim.models.keyedvectors.Vocab at 0x16ac8d700f0>,
#  '看见': <gensim.models.keyedvectors.Vocab at 0x16ac8d70128>,
#  '最迟': <gensim.models.keyedvectors.Vocab at 0x16ac8d70160>,
#  '一下子': <gensim.models.keyedvectors.Vocab at 0x16ac8d70198>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x16ac8d701d0>,
#  '意外': <gensim.models.keyedvectors.Vocab at 0x16ac8d70208>,
#  '谁': <gensim.models.keyedvectors.Vocab at 0x16ac8d70240>,
#  '改不了': <gensim.models.keyedvectors.Vocab at 0x16ac8d70278>,
#  '次': <gensim.models.keyedvectors.Vocab at 0x16ac8d702b0>,
#  '一千': <gensim.models.keyedvectors.Vocab at 0x16ac8d702e8>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x16ac8d70320>,
#  '链接': <gensim.models.keyedvectors.Vocab at 0x16ac8d70358>,
#  '哪': <gensim.models.keyedvectors.Vocab at 0x16ac8d70390>,
#  '填': <gensim.models.keyedvectors.Vocab at 0x16ac8d703c8>,
#  '公积金': <gensim.models.keyedvectors.Vocab at 0x16ac8d70400>,
#  '车': <gensim.models.keyedvectors.Vocab at 0x16ac8d70438>,
#  '没法': <gensim.models.keyedvectors.Vocab at 0x16ac8d70470>,
#  '提交': <gensim.models.keyedvectors.Vocab at 0x16ac8d704a8>,
#  '租赁': <gensim.models.keyedvectors.Vocab at 0x16ac8d704e0>,
#  '发票': <gensim.models.keyedvectors.Vocab at 0x16ac8d70518>,
#  '整么': <gensim.models.keyedvectors.Vocab at 0x16ac8d70550>,
#  '好久': <gensim.models.keyedvectors.Vocab at 0x16ac8d70588>,
#  '手机短信': <gensim.models.keyedvectors.Vocab at 0x16ac8d705c0>,
#  '锁': <gensim.models.keyedvectors.Vocab at 0x16ac8d705f8>,
#  '验证码': <gensim.models.keyedvectors.Vocab at 0x16ac8d70630>,
#  '收不到': <gensim.models.keyedvectors.Vocab at 0x16ac8d70668>,
#  '负面': <gensim.models.keyedvectors.Vocab at 0x16ac8d706a0>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x16ac8d706d8>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x16ac8d70710>,
#  '抽奖': <gensim.models.keyedvectors.Vocab at 0x16ac8d70748>,
#  '页面': <gensim.models.keyedvectors.Vocab at 0x16ac8d70780>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x16ac8d707b8>,
#  '一单': <gensim.models.keyedvectors.Vocab at 0x16ac8d707f0>,
#  '还算': <gensim.models.keyedvectors.Vocab at 0x16ac8d70828>,
#  '资质': <gensim.models.keyedvectors.Vocab at 0x16ac8d70860>,
#  '手动': <gensim.models.keyedvectors.Vocab at 0x16ac8d70898>,
#  '购买': <gensim.models.keyedvectors.Vocab at 0x16ac8d708d0>,
#  '最多': <gensim.models.keyedvectors.Vocab at 0x16ac8d70908>,
#  '能解': <gensim.models.keyedvectors.Vocab at 0x16ac8d70940>,
#  '用于': <gensim.models.keyedvectors.Vocab at 0x16ac8d70978>,
#  '双倍': <gensim.models.keyedvectors.Vocab at 0x16ac8d709b0>,
#  '返现': <gensim.models.keyedvectors.Vocab at 0x16ac8d709e8>,
#  '房贷': <gensim.models.keyedvectors.Vocab at 0x16ac8d70a20>,
#  '弄': <gensim.models.keyedvectors.Vocab at 0x16ac8d70a58>,
#  '每天': <gensim.models.keyedvectors.Vocab at 0x16ac8d70a90>,
#  '前面': <gensim.models.keyedvectors.Vocab at 0x16ac8d70ac8>,
#  '用集': <gensim.models.keyedvectors.Vocab at 0x16ac8d70b00>,
#  '分宝': <gensim.models.keyedvectors.Vocab at 0x16ac8d70b38>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x16ac8d70b70>,
#  '多点': <gensim.models.keyedvectors.Vocab at 0x16ac8d70ba8>,
#  '完能': <gensim.models.keyedvectors.Vocab at 0x16ac8d70be0>,
#  '加上': <gensim.models.keyedvectors.Vocab at 0x16ac8d70c18>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x16ac8d70c50>,
#  '没帮': <gensim.models.keyedvectors.Vocab at 0x16ac8d70c88>,
#  '完善': <gensim.models.keyedvectors.Vocab at 0x16ac8d70cc0>,
#  '购房': <gensim.models.keyedvectors.Vocab at 0x16ac8d70cf8>,
#  '合同': <gensim.models.keyedvectors.Vocab at 0x16ac8d70d30>,
#  '能行': <gensim.models.keyedvectors.Vocab at 0x16ac8d70d68>,
#  '领取': <gensim.models.keyedvectors.Vocab at 0x16ac8d70da0>,
#  '扣除': <gensim.models.keyedvectors.Vocab at 0x16ac8d70dd8>,
#  '降额': <gensim.models.keyedvectors.Vocab at 0x16ac8d70e10>,
#  '哈罗': <gensim.models.keyedvectors.Vocab at 0x16ac8d70e48>,
#  '快递': <gensim.models.keyedvectors.Vocab at 0x16ac8d70e80>,
#  '口碑': <gensim.models.keyedvectors.Vocab at 0x16ac8d70eb8>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x16ac8d70ef0>,
#  '用户': <gensim.models.keyedvectors.Vocab at 0x16ac8d70f28>,
#  '上用': <gensim.models.keyedvectors.Vocab at 0x16ac8d70f60>,
#  '账后': <gensim.models.keyedvectors.Vocab at 0x16ac8d70f98>,
#  '收取': <gensim.models.keyedvectors.Vocab at 0x16ac8d70fd0>,
#  '芝麻': <gensim.models.keyedvectors.Vocab at 0x16ac8d72048>,
#  '降': <gensim.models.keyedvectors.Vocab at 0x16ac8d72080>,
#  '卖东西': <gensim.models.keyedvectors.Vocab at 0x16ac8d720b8>,
#  '啥时候': <gensim.models.keyedvectors.Vocab at 0x16ac8d720f0>,
#  '充电': <gensim.models.keyedvectors.Vocab at 0x16ac8d72128>,
#  '费': <gensim.models.keyedvectors.Vocab at 0x16ac8d72160>,
#  '登陆': <gensim.models.keyedvectors.Vocab at 0x16ac8d72198>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x16ac8d721d0>,
#  '帐单': <gensim.models.keyedvectors.Vocab at 0x16ac8d72208>,
#  '选': <gensim.models.keyedvectors.Vocab at 0x16ac8d72240>,
#  '长': <gensim.models.keyedvectors.Vocab at 0x16ac8d72278>,
#  '抵扣': <gensim.models.keyedvectors.Vocab at 0x16ac8d722b0>,
#  '呗': <gensim.models.keyedvectors.Vocab at 0x16ac8d722e8>,
#  '关掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d72320>,
#  '网页': <gensim.models.keyedvectors.Vocab at 0x16ac8d72358>,
#  '版': <gensim.models.keyedvectors.Vocab at 0x16ac8d72390>,
#  '改过来': <gensim.models.keyedvectors.Vocab at 0x16ac8d723c8>,
#  '提升': <gensim.models.keyedvectors.Vocab at 0x16ac8d72400>,
#  '剩下': <gensim.models.keyedvectors.Vocab at 0x16ac8d72438>,
#  '已用': <gensim.models.keyedvectors.Vocab at 0x16ac8d72470>,
#  '免费': <gensim.models.keyedvectors.Vocab at 0x16ac8d724a8>,
#  '别的': <gensim.models.keyedvectors.Vocab at 0x16ac8d724e0>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x16ac8d72518>,
#  '赠送': <gensim.models.keyedvectors.Vocab at 0x16ac8d72550>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x16ac8d72588>,
#  '变成': <gensim.models.keyedvectors.Vocab at 0x16ac8d725c0>,
#  '今日': <gensim.models.keyedvectors.Vocab at 0x16ac8d725f8>,
#  '访问': <gensim.models.keyedvectors.Vocab at 0x16ac8d72630>,
#  '通讯录': <gensim.models.keyedvectors.Vocab at 0x16ac8d72668>,
#  '三个': <gensim.models.keyedvectors.Vocab at 0x16ac8d726a0>,
#  '滴滴': <gensim.models.keyedvectors.Vocab at 0x16ac8d726d8>,
#  '打车': <gensim.models.keyedvectors.Vocab at 0x16ac8d72710>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x16ac8d72748>,
#  '出账': <gensim.models.keyedvectors.Vocab at 0x16ac8d72780>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x16ac8d727b8>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x16ac8d727f0>,
#  '几号': <gensim.models.keyedvectors.Vocab at 0x16ac8d72828>,
#  '实际': <gensim.models.keyedvectors.Vocab at 0x16ac8d72860>,
#  '不符': <gensim.models.keyedvectors.Vocab at 0x16ac8d72898>,
#  '店家': <gensim.models.keyedvectors.Vocab at 0x16ac8d728d0>,
#  '查看': <gensim.models.keyedvectors.Vocab at 0x16ac8d72908>,
#  '具体': <gensim.models.keyedvectors.Vocab at 0x16ac8d72940>,
#  '老说': <gensim.models.keyedvectors.Vocab at 0x16ac8d72978>,
#  '认不出': <gensim.models.keyedvectors.Vocab at 0x16ac8d729b0>,
#  '如': <gensim.models.keyedvectors.Vocab at 0x16ac8d729e8>,
#  '明天': <gensim.models.keyedvectors.Vocab at 0x16ac8d72a20>,
#  '冲': <gensim.models.keyedvectors.Vocab at 0x16ac8d72a58>,
#  '流量': <gensim.models.keyedvectors.Vocab at 0x16ac8d72a90>,
#  '使': <gensim.models.keyedvectors.Vocab at 0x16ac8d72ac8>,
#  '提高': <gensim.models.keyedvectors.Vocab at 0x16ac8d72b00>,
#  '服务费': <gensim.models.keyedvectors.Vocab at 0x16ac8d72b38>,
#  '这么': <gensim.models.keyedvectors.Vocab at 0x16ac8d72b70>,
#  '贵': <gensim.models.keyedvectors.Vocab at 0x16ac8d72ba8>,
#  '正常': <gensim.models.keyedvectors.Vocab at 0x16ac8d72be0>,
#  '超市': <gensim.models.keyedvectors.Vocab at 0x16ac8d72c18>,
#  '饿': <gensim.models.keyedvectors.Vocab at 0x16ac8d72c50>,
#  '订餐': <gensim.models.keyedvectors.Vocab at 0x16ac8d72c88>,
#  '淘票票': <gensim.models.keyedvectors.Vocab at 0x16ac8d72cc0>,
#  '电影票': <gensim.models.keyedvectors.Vocab at 0x16ac8d72cf8>,
#  '不行': <gensim.models.keyedvectors.Vocab at 0x16ac8d72d30>,
#  '我查': <gensim.models.keyedvectors.Vocab at 0x16ac8d72d68>,
#  '按': <gensim.models.keyedvectors.Vocab at 0x16ac8d72da0>,
#  '算': <gensim.models.keyedvectors.Vocab at 0x16ac8d72dd8>,
#  '暂无': <gensim.models.keyedvectors.Vocab at 0x16ac8d72e10>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x16ac8d72e48>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x16ac8d72e80>,
#  '出去': <gensim.models.keyedvectors.Vocab at 0x16ac8d72eb8>,
#  '人脸识别': <gensim.models.keyedvectors.Vocab at 0x16ac8d72ef0>,
#  '还给': <gensim.models.keyedvectors.Vocab at 0x16ac8d72f28>,
#  '更换': <gensim.models.keyedvectors.Vocab at 0x16ac8d72f60>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x16ac8d72f98>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x16ac8d72fd0>,
#  '卡上': <gensim.models.keyedvectors.Vocab at 0x16ac8d75048>,
#  '真的': <gensim.models.keyedvectors.Vocab at 0x16ac8d75080>,
#  '数目': <gensim.models.keyedvectors.Vocab at 0x16ac8d750b8>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x16ac8d750f0>,
#  '我要': <gensim.models.keyedvectors.Vocab at 0x16ac8d75128>,
#  '忙': <gensim.models.keyedvectors.Vocab at 0x16ac8d75160>,
#  '综合': <gensim.models.keyedvectors.Vocab at 0x16ac8d75198>,
#  '多长时间': <gensim.models.keyedvectors.Vocab at 0x16ac8d751d0>,
#  '微贷': <gensim.models.keyedvectors.Vocab at 0x16ac8d75208>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x16ac8d75240>,
#  '看看': <gensim.models.keyedvectors.Vocab at 0x16ac8d75278>,
#  '行为': <gensim.models.keyedvectors.Vocab at 0x16ac8d752b0>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x16ac8d752e8>,
#  '入口': <gensim.models.keyedvectors.Vocab at 0x16ac8d75320>,
#  '三天': <gensim.models.keyedvectors.Vocab at 0x16ac8d75358>,
#  '明明': <gensim.models.keyedvectors.Vocab at 0x16ac8d75390>,
#  '虚拟': <gensim.models.keyedvectors.Vocab at 0x16ac8d753c8>,
#  '关了': <gensim.models.keyedvectors.Vocab at 0x16ac8d75400>,
#  '一半': <gensim.models.keyedvectors.Vocab at 0x16ac8d75438>,
#  '哪些': <gensim.models.keyedvectors.Vocab at 0x16ac8d75470>,
#  '给我发': <gensim.models.keyedvectors.Vocab at 0x16ac8d754a8>,
#  '电话': <gensim.models.keyedvectors.Vocab at 0x16ac8d754e0>,
#  '没少': <gensim.models.keyedvectors.Vocab at 0x16ac8d75518>,
#  '充错': <gensim.models.keyedvectors.Vocab at 0x16ac8d75550>,
#  '拿': <gensim.models.keyedvectors.Vocab at 0x16ac8d75588>,
#  '提钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d755c0>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x16ac8d755f8>,
#  '结算': <gensim.models.keyedvectors.Vocab at 0x16ac8d75630>,
#  '审核': <gensim.models.keyedvectors.Vocab at 0x16ac8d75668>,
#  '你们': <gensim.models.keyedvectors.Vocab at 0x16ac8d756a0>,
#  '天猫': <gensim.models.keyedvectors.Vocab at 0x16ac8d756d8>,
#  '迟': <gensim.models.keyedvectors.Vocab at 0x16ac8d75710>,
#  '两天': <gensim.models.keyedvectors.Vocab at 0x16ac8d75748>,
#  '回到': <gensim.models.keyedvectors.Vocab at 0x16ac8d75780>,
#  '免': <gensim.models.keyedvectors.Vocab at 0x16ac8d757b8>,
#  '一次性': <gensim.models.keyedvectors.Vocab at 0x16ac8d757f0>,
#  '发': <gensim.models.keyedvectors.Vocab at 0x16ac8d75828>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x16ac8d75860>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x16ac8d75898>,
#  '计算': <gensim.models.keyedvectors.Vocab at 0x16ac8d758d0>,
#  '几点': <gensim.models.keyedvectors.Vocab at 0x16ac8d75908>,
#  '实体店': <gensim.models.keyedvectors.Vocab at 0x16ac8d75940>,
#  '有没有': <gensim.models.keyedvectors.Vocab at 0x16ac8d75978>,
#  '退回来': <gensim.models.keyedvectors.Vocab at 0x16ac8d759b0>,
#  '它': <gensim.models.keyedvectors.Vocab at 0x16ac8d759e8>,
#  '状况': <gensim.models.keyedvectors.Vocab at 0x16ac8d75a20>,
#  '暂未': <gensim.models.keyedvectors.Vocab at 0x16ac8d75a58>,
#  '一块': <gensim.models.keyedvectors.Vocab at 0x16ac8d75a90>,
#  '归还': <gensim.models.keyedvectors.Vocab at 0x16ac8d75ac8>,
#  '完款': <gensim.models.keyedvectors.Vocab at 0x16ac8d75b00>,
#  '内容': <gensim.models.keyedvectors.Vocab at 0x16ac8d75b38>,
#  '第一次': <gensim.models.keyedvectors.Vocab at 0x16ac8d75b70>,
#  '欠款': <gensim.models.keyedvectors.Vocab at 0x16ac8d75ba8>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x16ac8d75be0>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x16ac8d75c18>,
#  '车票': <gensim.models.keyedvectors.Vocab at 0x16ac8d75c50>,
#  '提取': <gensim.models.keyedvectors.Vocab at 0x16ac8d75c88>,
#  '保证金': <gensim.models.keyedvectors.Vocab at 0x16ac8d75cc0>,
#  '调高': <gensim.models.keyedvectors.Vocab at 0x16ac8d75cf8>,
#  '刚用': <gensim.models.keyedvectors.Vocab at 0x16ac8d75d30>,
#  '商品价格': <gensim.models.keyedvectors.Vocab at 0x16ac8d75d68>,
#  '区别': <gensim.models.keyedvectors.Vocab at 0x16ac8d75da0>,
#  '最长': <gensim.models.keyedvectors.Vocab at 0x16ac8d75dd8>,
#  '不可': <gensim.models.keyedvectors.Vocab at 0x16ac8d75e10>,
#  '退掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d75e48>,
#  '想要': <gensim.models.keyedvectors.Vocab at 0x16ac8d75e80>,
#  '一月': <gensim.models.keyedvectors.Vocab at 0x16ac8d75eb8>,
#  '咋样': <gensim.models.keyedvectors.Vocab at 0x16ac8d75ef0>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x16ac8d75f28>,
#  '返': <gensim.models.keyedvectors.Vocab at 0x16ac8d75f60>,
#  '先息': <gensim.models.keyedvectors.Vocab at 0x16ac8d75f98>,
#  '后本': <gensim.models.keyedvectors.Vocab at 0x16ac8d75fd0>,
#  '全额': <gensim.models.keyedvectors.Vocab at 0x16ac8d76048>,
#  '像': <gensim.models.keyedvectors.Vocab at 0x16ac8d76080>,
#  '样子': <gensim.models.keyedvectors.Vocab at 0x16ac8d760b8>,
#  '申请人': <gensim.models.keyedvectors.Vocab at 0x16ac8d760f0>,
#  '假如': <gensim.models.keyedvectors.Vocab at 0x16ac8d76128>,
#  '去掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d76160>,
#  '占用': <gensim.models.keyedvectors.Vocab at 0x16ac8d76198>,
#  '几次': <gensim.models.keyedvectors.Vocab at 0x16ac8d761d0>,
#  '码收': <gensim.models.keyedvectors.Vocab at 0x16ac8d76208>,
#  '设置': <gensim.models.keyedvectors.Vocab at 0x16ac8d76240>,
#  '交费': <gensim.models.keyedvectors.Vocab at 0x16ac8d76278>,
#  '退出': <gensim.models.keyedvectors.Vocab at 0x16ac8d762b0>,
#  '活动': <gensim.models.keyedvectors.Vocab at 0x16ac8d762e8>,
#  '报名': <gensim.models.keyedvectors.Vocab at 0x16ac8d76320>,
#  '优惠券': <gensim.models.keyedvectors.Vocab at 0x16ac8d76358>,
#  '弹出': <gensim.models.keyedvectors.Vocab at 0x16ac8d76390>,
#  '您': <gensim.models.keyedvectors.Vocab at 0x16ac8d763c8>,
#  '暂': <gensim.models.keyedvectors.Vocab at 0x16ac8d76400>,
#  '是从': <gensim.models.keyedvectors.Vocab at 0x16ac8d76438>,
#  '有钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d76470>,
#  '店铺': <gensim.models.keyedvectors.Vocab at 0x16ac8d764a8>,
#  '打开': <gensim.models.keyedvectors.Vocab at 0x16ac8d764e0>,
#  '钱数': <gensim.models.keyedvectors.Vocab at 0x16ac8d76518>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x16ac8d76550>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x16ac8d76588>,
#  '返还': <gensim.models.keyedvectors.Vocab at 0x16ac8d765c0>,
#  '等到': <gensim.models.keyedvectors.Vocab at 0x16ac8d765f8>,
#  '机票': <gensim.models.keyedvectors.Vocab at 0x16ac8d76630>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x16ac8d76668>,
#  '撒': <gensim.models.keyedvectors.Vocab at 0x16ac8d766a0>,
#  '重复': <gensim.models.keyedvectors.Vocab at 0x16ac8d766d8>,
#  '工资': <gensim.models.keyedvectors.Vocab at 0x16ac8d76710>,
#  '负会': <gensim.models.keyedvectors.Vocab at 0x16ac8d76748>,
#  '行': <gensim.models.keyedvectors.Vocab at 0x16ac8d76780>,
#  '订': <gensim.models.keyedvectors.Vocab at 0x16ac8d767b8>,
#  '优先': <gensim.models.keyedvectors.Vocab at 0x16ac8d767f0>,
#  '当面': <gensim.models.keyedvectors.Vocab at 0x16ac8d76828>,
#  '替': <gensim.models.keyedvectors.Vocab at 0x16ac8d76860>,
#  '他人': <gensim.models.keyedvectors.Vocab at 0x16ac8d76898>,
#  '好久没': <gensim.models.keyedvectors.Vocab at 0x16ac8d768d0>,
#  '后要': <gensim.models.keyedvectors.Vocab at 0x16ac8d76908>,
#  '预期': <gensim.models.keyedvectors.Vocab at 0x16ac8d76940>,
#  '下面': <gensim.models.keyedvectors.Vocab at 0x16ac8d76978>,
#  '免单': <gensim.models.keyedvectors.Vocab at 0x16ac8d769b0>,
#  '上限': <gensim.models.keyedvectors.Vocab at 0x16ac8d769e8>,
#  '总是': <gensim.models.keyedvectors.Vocab at 0x16ac8d76a20>,
#  '帐户': <gensim.models.keyedvectors.Vocab at 0x16ac8d76a58>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x16ac8d76a90>,
#  '安': <gensim.models.keyedvectors.Vocab at 0x16ac8d76ac8>,
#  '计划': <gensim.models.keyedvectors.Vocab at 0x16ac8d76b00>,
#  '微信': <gensim.models.keyedvectors.Vocab at 0x16ac8d76b38>,
#  '涨': <gensim.models.keyedvectors.Vocab at 0x16ac8d76b70>,
#  '每期': <gensim.models.keyedvectors.Vocab at 0x16ac8d76ba8>,
#  '便宜': <gensim.models.keyedvectors.Vocab at 0x16ac8d76be0>,
#  '经常': <gensim.models.keyedvectors.Vocab at 0x16ac8d76c18>,
#  '卷': <gensim.models.keyedvectors.Vocab at 0x16ac8d76c50>,
#  '能免': <gensim.models.keyedvectors.Vocab at 0x16ac8d76c88>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x16ac8d76cc0>,
#  '_': <gensim.models.keyedvectors.Vocab at 0x16ac8d76cf8>,
#  '支': <gensim.models.keyedvectors.Vocab at 0x16ac8d76d30>,
#  '余利': <gensim.models.keyedvectors.Vocab at 0x16ac8d76d68>,
#  '现有': <gensim.models.keyedvectors.Vocab at 0x16ac8d76da0>,
#  '只用': <gensim.models.keyedvectors.Vocab at 0x16ac8d76dd8>,
#  '一百元': <gensim.models.keyedvectors.Vocab at 0x16ac8d76e10>,
#  '三百多': <gensim.models.keyedvectors.Vocab at 0x16ac8d76e48>,
#  '一笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d76e80>,
#  '封掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d76eb8>,
#  '受': <gensim.models.keyedvectors.Vocab at 0x16ac8d76ef0>,
#  '尾款': <gensim.models.keyedvectors.Vocab at 0x16ac8d76f28>,
#  '总额': <gensim.models.keyedvectors.Vocab at 0x16ac8d76f60>,
#  '调整': <gensim.models.keyedvectors.Vocab at 0x16ac8d76f98>,
#  '单子': <gensim.models.keyedvectors.Vocab at 0x16ac8d76fd0>,
#  '险': <gensim.models.keyedvectors.Vocab at 0x16ac8d79048>,
#  '农信': <gensim.models.keyedvectors.Vocab at 0x16ac8d79080>,
#  '很久': <gensim.models.keyedvectors.Vocab at 0x16ac8d790b8>,
#  '几时': <gensim.models.keyedvectors.Vocab at 0x16ac8d790f0>,
#  '没收': <gensim.models.keyedvectors.Vocab at 0x16ac8d79128>,
#  '到货': <gensim.models.keyedvectors.Vocab at 0x16ac8d79160>,
#  '单笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d79198>,
#  '寄': <gensim.models.keyedvectors.Vocab at 0x16ac8d791d0>,
#  '回去': <gensim.models.keyedvectors.Vocab at 0x16ac8d79208>,
#  '处理': <gensim.models.keyedvectors.Vocab at 0x16ac8d79240>,
#  '奖励': <gensim.models.keyedvectors.Vocab at 0x16ac8d79278>,
#  '三笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d792b0>,
#  '订单': <gensim.models.keyedvectors.Vocab at 0x16ac8d792e8>,
#  '延迟': <gensim.models.keyedvectors.Vocab at 0x16ac8d79320>,
#  '可不可以': <gensim.models.keyedvectors.Vocab at 0x16ac8d79358>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x16ac8d79390>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x16ac8d793c8>,
#  '客服': <gensim.models.keyedvectors.Vocab at 0x16ac8d79400>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x16ac8d79438>,
#  '掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d79470>,
#  '解冻': <gensim.models.keyedvectors.Vocab at 0x16ac8d794a8>,
#  '信誉': <gensim.models.keyedvectors.Vocab at 0x16ac8d794e0>,
#  '是因为': <gensim.models.keyedvectors.Vocab at 0x16ac8d79518>,
#  '注册': <gensim.models.keyedvectors.Vocab at 0x16ac8d79550>,
#  '转移': <gensim.models.keyedvectors.Vocab at 0x16ac8d79588>,
#  '算是': <gensim.models.keyedvectors.Vocab at 0x16ac8d795c0>,
#  '最晚': <gensim.models.keyedvectors.Vocab at 0x16ac8d795f8>,
#  '判定': <gensim.models.keyedvectors.Vocab at 0x16ac8d79630>,
#  '不少': <gensim.models.keyedvectors.Vocab at 0x16ac8d79668>,
#  '单': <gensim.models.keyedvectors.Vocab at 0x16ac8d796a0>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x16ac8d796d8>,
#  '没绑': <gensim.models.keyedvectors.Vocab at 0x16ac8d79710>,
#  '能否': <gensim.models.keyedvectors.Vocab at 0x16ac8d79748>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x16ac8d79780>,
#  '本金': <gensim.models.keyedvectors.Vocab at 0x16ac8d797b8>,
#  '沃尔玛': <gensim.models.keyedvectors.Vocab at 0x16ac8d797f0>,
#  '期限': <gensim.models.keyedvectors.Vocab at 0x16ac8d79828>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x16ac8d79860>,
#  '低于': <gensim.models.keyedvectors.Vocab at 0x16ac8d79898>,
#  '点击': <gensim.models.keyedvectors.Vocab at 0x16ac8d798d0>,
#  '出租车': <gensim.models.keyedvectors.Vocab at 0x16ac8d79908>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x16ac8d79940>,
#  '天数': <gensim.models.keyedvectors.Vocab at 0x16ac8d79978>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x16ac8d799b0>,
#  '小号': <gensim.models.keyedvectors.Vocab at 0x16ac8d799e8>,
#  '旧': <gensim.models.keyedvectors.Vocab at 0x16ac8d79a20>,
#  '获得': <gensim.models.keyedvectors.Vocab at 0x16ac8d79a58>,
#  '奖励金': <gensim.models.keyedvectors.Vocab at 0x16ac8d79a90>,
#  '去除': <gensim.models.keyedvectors.Vocab at 0x16ac8d79ac8>,
#  '咋个': <gensim.models.keyedvectors.Vocab at 0x16ac8d79b00>,
#  '负': <gensim.models.keyedvectors.Vocab at 0x16ac8d79b38>,
#  '为什': <gensim.models.keyedvectors.Vocab at 0x16ac8d79b70>,
#  '取出': <gensim.models.keyedvectors.Vocab at 0x16ac8d79ba8>,
#  '九号': <gensim.models.keyedvectors.Vocab at 0x16ac8d79be0>,
#  '详细': <gensim.models.keyedvectors.Vocab at 0x16ac8d79c18>,
#  '除了': <gensim.models.keyedvectors.Vocab at 0x16ac8d79c50>,
#  '地方': <gensim.models.keyedvectors.Vocab at 0x16ac8d79c88>,
#  '空白': <gensim.models.keyedvectors.Vocab at 0x16ac8d79cc0>,
#  '字': <gensim.models.keyedvectors.Vocab at 0x16ac8d79cf8>,
#  '宝存': <gensim.models.keyedvectors.Vocab at 0x16ac8d79d30>,
#  '进去': <gensim.models.keyedvectors.Vocab at 0x16ac8d79d68>,
#  '按时': <gensim.models.keyedvectors.Vocab at 0x16ac8d79da0>,
#  '可是': <gensim.models.keyedvectors.Vocab at 0x16ac8d79dd8>,
#  '超期': <gensim.models.keyedvectors.Vocab at 0x16ac8d79e10>,
#  '解除': <gensim.models.keyedvectors.Vocab at 0x16ac8d79e48>,
#  '没事': <gensim.models.keyedvectors.Vocab at 0x16ac8d79e80>,
#  '兑换': <gensim.models.keyedvectors.Vocab at 0x16ac8d79eb8>,
#  '找到': <gensim.models.keyedvectors.Vocab at 0x16ac8d79ef0>,
#  '完全': <gensim.models.keyedvectors.Vocab at 0x16ac8d79f28>,
#  '功能': <gensim.models.keyedvectors.Vocab at 0x16ac8d79f60>,
#  '我开': <gensim.models.keyedvectors.Vocab at 0x16ac8d79f98>,
#  '店': <gensim.models.keyedvectors.Vocab at 0x16ac8d79fd0>,
#  '店面': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b048>,
#  '抽到': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b080>,
#  '劵': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b0b8>,
#  '贷': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b0f0>,
#  '催': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b128>,
#  '额外': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b160>,
#  '程序': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b198>,
#  '宝中': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b1d0>,
#  '请': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b208>,
#  '用法': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b240>,
#  '代': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b278>,
#  '笔笔': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b2b0>,
#  '抽': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b2e8>,
#  '中奖': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b320>,
#  '六期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b358>,
#  '稍后': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b390>,
#  '再试': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b3c8>,
#  '固定': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b400>,
#  '每日': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b438>,
#  '所有': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b470>,
#  '平台': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b4a8>,
#  '什么样': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b4e0>,
#  '进不去': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b518>,
#  '万五': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b550>,
#  '不得': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b588>,
#  '差': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b5c0>,
#  '扫脸': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b5f8>,
#  '不扣': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b630>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b668>,
#  '密付': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b6a0>,
#  '回复': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b6d8>,
#  '不见': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b710>,
#  '办': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b748>,
#  '能充': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b780>,
#  '转接': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b7b8>,
#  '领了': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b7f0>,
#  '回来': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b828>,
#  '出来': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b860>,
#  '不起': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b898>,
#  '日到': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b8d0>,
#  '凭': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b908>,
#  '要收': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b940>,
#  '额': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b978>,
#  '金': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b9b0>,
#  '一个月': <gensim.models.keyedvectors.Vocab at 0x16ac8d7b9e8>,
#  '十天': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ba20>,
#  '问下': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ba58>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ba90>,
#  '越高': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bac8>,
#  '一期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bb00>,
#  '晚点': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bb38>,
#  '我摩拜': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bb70>,
#  '压': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bba8>,
#  '确': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bbe0>,
#  '失败': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bc18>,
#  '只要': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bc50>,
#  '扣费': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bc88>,
#  '得到': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bcc0>,
#  '输': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bcf8>,
#  '给钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bd30>,
#  '扣过': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bd68>,
#  '宝转': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bda0>,
#  '进账': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bdd8>,
#  '生成': <gensim.models.keyedvectors.Vocab at 0x16ac8d7be10>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x16ac8d7be48>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x16ac8d7be80>,
#  '上次': <gensim.models.keyedvectors.Vocab at 0x16ac8d7beb8>,
#  '半个': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bef0>,
#  '定期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bf28>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bf60>,
#  '缴费': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bf98>,
#  '随时': <gensim.models.keyedvectors.Vocab at 0x16ac8d7bfd0>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e048>,
#  '老是': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e080>,
#  '款项': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e0b8>,
#  '紧急': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e0f0>,
#  '联系人': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e128>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e160>,
#  '网购': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e198>,
#  '预订': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e1d0>,
#  '一款': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e208>,
#  '定金': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e240>,
#  '钱付': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e278>,
#  '打算': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e2b0>,
#  '三期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e2e8>,
#  '停': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e320>,
#  '消除': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e358>,
#  '对方': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e390>,
#  '发货': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e3c8>,
#  '吖': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e400>,
#  '每次': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e438>,
#  '开不起': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e470>,
#  '大于': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e4a8>,
#  '等于': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e4e0>,
#  '身份': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e518>,
#  '填写': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e550>,
#  '关联': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e588>,
#  '一分钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e5c0>,
#  '优惠': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e5f8>,
#  '礼包': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e630>,
#  '网商': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e668>,
#  '怎么弄': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e6a0>,
#  '最底': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e6d8>,
#  '好多钱': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e710>,
#  '期间': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e748>,
#  '指纹': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e780>,
#  '下载': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e7b8>,
#  '以下': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e7f0>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e828>,
#  '三百': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e860>,
#  '五百': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e898>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e8d0>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e908>,
#  '扣掉': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e940>,
#  '块': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e978>,
#  '毛': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e9b0>,
#  '标识': <gensim.models.keyedvectors.Vocab at 0x16ac8d7e9e8>,
#  '标志': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ea20>,
#  '记入': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ea58>,
#  '个人信用': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ea90>,
#  '商店': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eac8>,
#  '买点': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eb00>,
#  '短': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eb38>,
#  '一点': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eb70>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eba8>,
#  '升': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ebe0>,
#  '以经': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ec18>,
#  '末': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ec50>,
#  '恢复正常': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ec88>,
#  '随': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ecc0>,
#  '几': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ecf8>,
#  '下期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ed30>,
#  '啦': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ed68>,
#  '多扣': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eda0>,
#  '兑现': <gensim.models.keyedvectors.Vocab at 0x16ac8d7edd8>,
#  '我试': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ee10>,
#  '待': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ee48>,
#  '调低': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ee80>,
#  '汇率': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eeb8>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x16ac8d7eef0>,
#  '选择': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ef28>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ef60>,
#  '几期': <gensim.models.keyedvectors.Vocab at 0x16ac8d7ef98>,
#  '试用': <gensim.models.keyedvectors.Vocab at 0x16ac8d7efd0>,
#  '能用': <gensim.models.keyedvectors.Vocab at 0x16ac8d80048>,
#  '全都': <gensim.models.keyedvectors.Vocab at 0x16ac8d80080>,
#  '扫': <gensim.models.keyedvectors.Vocab at 0x16ac8d800b8>,
#  '过不去': <gensim.models.keyedvectors.Vocab at 0x16ac8d800f0>,
#  '点错': <gensim.models.keyedvectors.Vocab at 0x16ac8d80128>,
#  '能分': <gensim.models.keyedvectors.Vocab at 0x16ac8d80160>,
#  '商场': <gensim.models.keyedvectors.Vocab at 0x16ac8d80198>,
#  '共用': <gensim.models.keyedvectors.Vocab at 0x16ac8d801d0>,
#  '一份': <gensim.models.keyedvectors.Vocab at 0x16ac8d80208>,
#  ...}

# %% [markdown]
# * 保存模型

# %%
doc_name='../model/model_doc'
doc2vec_doc.save(doc_name)
#model = Doc2Vec.load(fname)

# %% [markdown]
# * 如果不想训练，可以删掉训练文件

# %%
#model.delete_temporary_training_data(keep_doctags_vectors=True, \
#                                     keep_inference=True)

# %%
#计算句子的向量
test_vec=doc2vec_doc.infer_vector(['借呗', '换网', '商贷'])
#test_vec=doc2vec_doc.infer_vector(['每周', '二', '花呗'])

# %%
doc2vec_doc.docvecs.similarity
# Out:
# <bound method Doc2VecKeyedVectors.similarity of <gensim.models.keyedvectors.Doc2VecKeyedVectors object at 0x0000016AC8CACE48>>

# %%
#计算与内容类似的文字
for i,j in doc2vec_doc.docvecs.most_similar([test_vec],topn=train.shape[0])[:5]:
    print(i,j,sent_cut[i])
# Out:
# 77590 0.6782088875770569 每周 二 花呗
# 11557 0.6743882298469543 花呗 双十 一免 单
# 188572 0.6585396528244019 需求 人工 客服
# 192725 0.6563206315040588 借呗 换网 商贷
# 204871 0.6553398370742798 网商 贷换 借呗

# %%
ranks=[]
second=[]
for words,tags in train_corpus:
    vec=docvec.infer_vector(words)
    similar=docvec.docvecs.most_similar([vec],topn=len(train_corpus))
    rank=[doc for doc, sim in similar].index(tags[0])
    ranks.append(rank)
    second.append(similar[1])

# %% [markdown]
# * doc2vec准确率判断
# * 验证句子训练的效果。看看与自己最相似的是不是自己
# * 看一下计算出来自己排在哪一个名词，如果是0自己与自己相似

# %% [markdown]
# ### 3.2 自己构造tagged

# %%
#构造自己想要的
train_corpus=[]
for tags,words in enumerate(sent_cut):
    train_corpus.append(gensim.models.doc2vec.TaggedDocument(words,[tags]))

# %%
docvec=gensim.models.Doc2Vec(train_corpus,epochs=100)

# %% [markdown]
# ## 4 关键字提取

# %%
hb='为何我无法申请开通花呗信用卡收款'
def extra_tags_by_text(text,*arg):
    '''
    提取关键字并按照文章顺序返回。
    不能使用带权重和标签的返回值。 
    '''
    extra=jieba.analyse.extract_tags(text,*arg)
    index=[text.find(i) for i in extra ]
    index=np.argsort(index)
    extra=[extra[i] for i in index]
    return extra
print(extra_tags_by_text(hb))
hb2=extra_tags_by_text(hb)
